# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.shape
# Out:
# (400, 5)

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df['Purchased'].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
# first of all, drop the User ID column
df = df.drop('User ID', axis = 1)

# %%
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0    Male   19            19000          0
# 1    Male   35            20000          0
# 2  Female   26            43000          0
# 3  Female   27            57000          0
# 4    Male   19            76000          0

# %%
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %%
# split the data into train and test
# X = df.drop('Purchased', axis = 1)

# %%
# Y = df['Purchased']

# %%
# X

# %%
# Y

# %%
# Label encode: Gender column 
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
df['Gender'] = encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         0   26            43000          0
# 3         0   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       0   46            41000          1
# 396       1   51            23000          1
# 397       0   50            20000          1
# 398       1   36            33000          0
# 399       0   49            36000          1
#
# [400 rows x 4 columns]

# %%
X = df.drop('Purchased', axis = 1)
Y = df['Purchased']

X
# Out:
#      Gender  Age  EstimatedSalary
# 0         1   19            19000
# 1         1   35            20000
# 2         0   26            43000
# 3         0   27            57000
# 4         1   19            76000
# ..      ...  ...              ...
# 395       0   46            41000
# 396       1   51            23000
# 397       0   50            20000
# 398       1   36            33000
# 399       0   49            36000
#
# [400 rows x 3 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
# splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)


# SCALING
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train = ss.fit_transform(X_train) #z-score se apan scale kr rahe
X_test = ss.transform(X_test) #mean and std X_train ka hai, apan sirf transform kr rahe

# %%
# X_train.shape
X_train
# Out:
# array([[-0.97530483, -1.00993752, -1.18104385],
#        [ 1.02532046, -1.20380674, -1.45563869],
#        [ 1.02532046, -0.2344606 , -0.60134363],
#        [-0.97530483, -1.68847982,  0.37499358],
#        [ 1.02532046, -0.04059137, -0.50981202],
#        [ 1.02532046, -0.9130029 , -1.15053331],
#        [ 1.02532046, -1.10687213, -1.63870192],
#        [-0.97530483,  0.4440817 ,  0.3139725 ],
#        [ 1.02532046, -0.81606829, -0.8149174 ],
#        [ 1.02532046,  0.05634324, -0.32674879],
#        [-0.97530483,  0.05634324, -0.60134363],
#        [-0.97530483, -1.39767597, -0.11317503],
#        [-0.97530483,  0.05634324,  1.32082025],
#        [ 1.02532046, -0.52526444,  0.92418326],
#        [ 1.02532046, -1.10687213,  0.49703573],
#        [ 1.02532046, -0.13752598, -1.12002277],
#        [ 1.02532046, -0.71913367,  1.99205208],
#        [-0.97530483, -0.2344606 , -0.14368556],
#        [-0.97530483, -0.2344606 ,  0.0698882 ],
#        [-0.97530483,  0.15327786, -0.26572772],
# ...

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, Y_train) #model ban jata fit krne se
# Out:
# LogisticRegression()

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
Y_train.value_counts()
# Out:
# 0    213
# 1    107
# Name: Purchased, dtype: int64

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, Y_pred)
cm
# Out:
# array([[43,  1],
#        [12, 24]], dtype=int64)

# %%
# Performance metrics
tp = cm[0][0]
fp = cm[0][1]
fn = cm[1][0]
tn = cm[1][1]

# %%
# Precision:
precision = tp/(tp+fp)

# Recall:
recall = tp/(tp+fn)

# Accuracy:
accuracy = (tp+tn)/(tp+fp+fn+tn)

# f1 score:
f1_score = 2 * (recall*precision)/(recall + precision)

print(precision, recall, accuracy, f1_score)
# Out:
# 0.9772727272727273 0.7818181818181819 0.8375 0.8686868686868686
